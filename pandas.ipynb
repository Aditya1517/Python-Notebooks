# %%
# pandas library is used for read and process data
import pandas as pd

# %%
df = pd.read_csv('weather_data_nyc.csv')
df
# Out:
#            date  maximum temperature  minimum temperature  \
# 0      1-1-2016                   42                   34
# 1      2-1-2016                   40                   32
# 2      3-1-2016                   45                   35
# 3      4-1-2016                   36                   14
# 4      5-1-2016                   29                   11
# ..          ...                  ...                  ...
# 361  27-12-2016                   60                   40
# 362  28-12-2016                   40                   34
# 363  29-12-2016                   46                   33
# 364  30-12-2016                   40                   33
# 365  31-12-2016                   44                   31
#
#      average temperature precipitation snow fall snow depth
# 0                   38.0          0.00       0.0          0
# 1                   36.0          0.00       0.0          0
# 2                   40.0          0.00       0.0          0
# ...

# %%
  df['maximum temperature'].max()
# Out:
# 96

# %%
# Convert 'T' and other non-numeric entries to NaN, then fill them with 0
df['precipitation_clean'] = pd.to_numeric(df['precipitation'], errors='coerce').fillna(0)

# Now filter for dates with actual rain
rain_dates = df['date'][df['precipitation_clean'] > 0]
print(rain_dates)
# Out:
# 9       10-1-2016
# 15      16-1-2016
# 16      17-1-2016
# 21      22-1-2016
# 22      23-1-2016
#           ...
# 352    18-12-2016
# 358    24-12-2016
# 360    26-12-2016
# 363    29-12-2016
# 364    30-12-2016
# Name: date, Length: 116, dtype: object

# %%
# Remove any leading/trailing whitespace from all column names
df.columns = df.columns.str.strip()

# Now you can safely access the column
print(df['average temperature'].mean())
# Out:
# 57.21584699453552

# %%
# dataframes in pandas
df.shape
# Out:
# (366, 8)

# %%
df.head() # prints few rows of data
# Out:
#        date  maximum temperature  minimum temperature  average temperature  \
# 0  1-1-2016                   42                   34                 38.0
# 1  2-1-2016                   40                   32                 36.0
# 2  3-1-2016                   45                   35                 40.0
# 3  4-1-2016                   36                   14                 25.0
# 4  5-1-2016                   29                   11                 20.0
#
#   precipitation snow fall snow depth  precipitation_clean
# 0          0.00       0.0          0                  0.0
# 1          0.00       0.0          0                  0.0
# 2          0.00       0.0          0                  0.0
# 3          0.00       0.0          0                  0.0
# 4          0.00       0.0          0                  0.0

# %%
df.tail() # prints few rows of data
# Out:
#            date  maximum temperature  minimum temperature  \
# 361  27-12-2016                   60                   40
# 362  28-12-2016                   40                   34
# 363  29-12-2016                   46                   33
# 364  30-12-2016                   40                   33
# 365  31-12-2016                   44                   31
#
#      average temperature precipitation snow fall snow depth  \
# 361                 50.0             0         0          0
# 362                 37.0             0         0          0
# 363                 39.5          0.39         0          0
# 364                 36.5          0.01         T          0
# 365                 37.5             0         0          0
#
#      precipitation_clean
# 361                 0.00
# 362                 0.00
# 363                 0.39
# 364                 0.01
# 365                 0.00

# %%
# slicing
df[2:5]
# Out:
#        date  maximum temperature  minimum temperature  average temperature  \
# 2  3-1-2016                   45                   35                 40.0
# 3  4-1-2016                   36                   14                 25.0
# 4  5-1-2016                   29                   11                 20.0
#
#   precipitation snow fall snow depth  precipitation_clean
# 2          0.00       0.0          0                  0.0
# 3          0.00       0.0          0                  0.0
# 4          0.00       0.0          0                  0.0

# %%
df.columns
# Out:
# Index(['date', 'maximum temperature', 'minimum temperature',
#        'average temperature', 'precipitation', 'snow fall', 'snow depth',
#        'precipitation_clean'],
#       dtype='object')

# %%
df.date
# Out:
# 0        1-1-2016
# 1        2-1-2016
# 2        3-1-2016
# 3        4-1-2016
# 4        5-1-2016
#           ...
# 361    27-12-2016
# 362    28-12-2016
# 363    29-12-2016
# 364    30-12-2016
# 365    31-12-2016
# Name: date, Length: 366, dtype: object

# %%
df['date']
# Out:
# 0        1-1-2016
# 1        2-1-2016
# 2        3-1-2016
# 3        4-1-2016
# 4        5-1-2016
#           ...
# 361    27-12-2016
# 362    28-12-2016
# 363    29-12-2016
# 364    30-12-2016
# 365    31-12-2016
# Name: date, Length: 366, dtype: object

# %%
df[['date','precipitation']]
# Out:
#            date precipitation
# 0      1-1-2016          0.00
# 1      2-1-2016          0.00
# 2      3-1-2016          0.00
# 3      4-1-2016          0.00
# 4      5-1-2016          0.00
# ..          ...           ...
# 361  27-12-2016             0
# 362  28-12-2016             0
# 363  29-12-2016          0.39
# 364  30-12-2016          0.01
# 365  31-12-2016             0
#
# [366 rows x 2 columns]

# %%
df['maximum temperature'].describe()
# Out:
# count    366.000000
# mean      64.625683
# std       18.041787
# min       15.000000
# 25%       50.000000
# 50%       64.500000
# 75%       81.000000
# max       96.000000
# Name: maximum temperature, dtype: float64

# %%
df[df['maximum temperature'] == df['maximum temperature'].max()]
# Out:
#           date  maximum temperature  minimum temperature  average temperature  \
# 204  23-7-2016                   96                   80                 88.0
# 225  13-8-2016                   96                   81                 88.5
#
#     precipitation snow fall snow depth  precipitation_clean
# 204             0         0          0                  0.0
# 225             0         0          0                  0.0

# %%
df.date[df['maximum temperature'] == df['maximum temperature'].max()]
# Out:
# 204    23-7-2016
# 225    13-8-2016
# Name: date, dtype: object

# %%
# read and write in csv and xls files
df = pd.read_excel('weather_data_nyc.xlsx')
df
# Out:
#           date  maximum temperature  minimum temperature  average temperature  \
# 0   2016-01-01                   42                   34                 38.0
# 1   2016-01-02                   40                   32                 36.0
# 2   2016-01-03                   45                   35                 40.0
# 3   2016-01-04                   36                   14                 25.0
# 4   2016-01-05                   29                   11                 20.0
# ..         ...                  ...                  ...                  ...
# 361 2016-12-27                   60                   40                 50.0
# 362 2016-12-28                   40                   34                 37.0
# 363 2016-12-29                   46                   33                 39.5
# 364 2016-12-30                   40                   33                 36.5
# 365 2016-12-31                   44                   31                 37.5
#
# ...

# %%
df.to_csv('new.csv') # index will be stored here
df.to_csv('new_noindex.csv', index=False) # index will not be stored here
# aslo we can save data in excel file

# %%
g = df.groupby('maximum temperature')
g

# %%
for temperature, df in g:
    print(temperature)
    print(df)
# Out:
# 15
#          date  maximum temperature  minimum temperature  average temperature  \
# 44 2016-02-14                   15                   -1                  7.0
#
#    precipitation snow fall snow depth
# 44             0         0          0
# 22
#          date  maximum temperature  minimum temperature  average temperature  \
# 43 2016-02-13                   22                    6                 14.0
#
#    precipitation snow fall snow depth
# 43             0         0          0
# 27
#           date  maximum temperature  minimum temperature  average temperature  \
# 22  2016-01-23                   27                   24                 25.5
# 42  2016-02-12                   27                   15                 21.0
# 350 2016-12-16                   27                   17                 22.0
#
#     precipitation snow fall snow depth
# 22           2.31      27.3          6
# 42              0         0          0
# 350             0         0          0
# 28
# ...

# %%
g.get_group(60)
# Out:
#           date  maximum temperature  minimum temperature  average temperature  \
# 54  2016-02-24                   60                   36                 48.0
# 58  2016-02-28                   60                   38                 49.0
# 66  2016-03-07                   60                   36                 48.0
# 116 2016-04-26                   60                   47                 53.5
# 122 2016-05-02                   60                   45                 52.5
# 127 2016-05-07                   60                   48                 54.0
# 333 2016-11-29                   60                   51                 55.5
# 361 2016-12-27                   60                   40                 50.0
#
#     precipitation snow fall snow depth
# 54           1.22         0          0
# 58              0         0          0
# 66              0         0          0
# 116          0.24         0          0
# 122          0.04         0          0
# ...

# %%
df.columns = df.columns.str.strip()
print(df.dtypes)
g = df.groupby('date')
print(g.max(numeric_only=True))
# Out:
# city           object
# temperature     int64
# humidity        int64
# dtype: object
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-a2d83657e34f> in <cell line: 0>()
#       1 df.columns = df.columns.str.strip()
#       2 print(df.dtypes)
# ----> 3 g = df.groupby('date')
#       4 print(g.max(numeric_only=True))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
# ...

# %%
# Select specific numeric columns for the mean calculation
# Ensure to exclude non-numeric columns like 'date'
numeric_cols = df.select_dtypes(include=['number']).columns
print(g[numeric_cols].mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-7e267c6a9f36> in <cell line: 0>()
#       2 # Ensure to exclude non-numeric columns like 'date'
#       3 numeric_cols = df.select_dtypes(include=['number']).columns
# ----> 4 print(g[numeric_cols].mean())
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1949                 "Use a list instead."
#    1950             )
# -> 1951         return super().__getitem__(key)
#    1952
#    1953     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     237             if len(self.obj.columns.intersection(key)) != len(set(key)):
#     238                 bad_keys = list(set(key).difference(self.obj.columns))
# ...

# %%
# concatinatino of dataframes
india_weather = pd.DataFrame({ # saving dataframes using dictionaries
    "city": ["mumbai","delhi","bangalore"],
    "temperature": [32,45,30],
    "humidity": [80, 60, 78]
})
india_weather
# Out:
#         city  temperature  humidity
# 0     mumbai           32        80
# 1      delhi           45        60
# 2  bangalore           30        78

# %%
us_weather = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
    "humidity": [68, 65, 75]
})
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df = pd.concat([india_weather, us_weather])
df
# Out:
#         city  temperature  humidity
# 0     mumbai           32        80
# 1      delhi           45        60
# 2  bangalore           30        78
# 0   new york           21        68
# 1    chicago           14        65
# 2    orlando           35        75

# %%
df
# Out:
#         city  temperature  humidity
# 0     mumbai           32        80
# 1      delhi           45        60
# 2  bangalore           30        78
# 0   new york           21        68
# 1    chicago           14        65
# 2    orlando           35        75

# %%
df = pd.concat([india_weather, us_weather], axis=1)
df
# Out:
#         city  temperature  humidity      city  temperature  humidity
# 0     mumbai           32        80  new york           21        68
# 1      delhi           45        60   chicago           14        65
# 2  bangalore           30        78   orlando           35        75

# %%
# merge dataframes
temperature_df = pd.DataFrame({
    "city": ["mumbai","delhi","bangalore", 'hyderabad'],
    "temperature": [32,45,30,40]})
temperature_df
# Out:
#         city  temperature
# 0     mumbai           32
# 1      delhi           45
# 2  bangalore           30
# 3  hyderabad           40

# %%
humidity_df = pd.DataFrame({
    "city": ["delhi","mumbai","bangalore"],
    "humidity": [68, 65, 75]})
humidity_df
# Out:
#         city  humidity
# 0      delhi        68
# 1     mumbai        65
# 2  bangalore        75

# %%
df = pd.merge(temperature_df, humidity_df, on='city')
df
# Out:
#         city  temperature  humidity
# 0     mumbai           32        65
# 1      delhi           45        68
# 2  bangalore           30        75

# %%
# outer join
df = pd.merge(temperature_df, humidity_df, on='city', how='outer')
df
# Out:
#         city  temperature  humidity
# 0  bangalore           30      75.0
# 1      delhi           45      68.0
# 2  hyderabad           40       NaN
# 3     mumbai           32      65.0

# %%
# numerical indexing
df = pd.DataFrame([1,2,3,4,5,6,7,8,9,19], index=[49,48,47,46,45, 1, 2, 3, 4, 5])
df
# Out:
#      0
# 49   1
# 48   2
# 47   3
# 46   4
# 45   5
# 1    6
# 2    7
# 3    8
# 4    9
# 5   19

# %%
s = pd.Series([10, 20, 30, 40, 50])
print(s.loc[:2])  # Prints values at index 0, 1, 2
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s.iloc[:2]
# Out:
# 0    10
# 1    20
# dtype: int64
